# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\retam\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\retam\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\retam\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\retam\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\retam\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
df=pd.read_csv('csv_files\Data_1.csv')
df # in this csv file each col has one Nan value
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# the second approach of removing null values from the data
#using simple imputer
imputer= SimpleImputer(missing_values = np.nan,strategy='most_frequent')
imputer.fit(df.iloc[:,1:3].values)
# imputer.fit(df.iloc[:,3:].values)
df.iloc[:,1:3] = imputer.transform(df.iloc[:,1:3].values)
# df.iloc[:,3:] = imputer.transform(df.iloc[:,3:].values)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.iloc[:,3:].values
# Out:
# array([['Yes'],
#        ['Yes'],
#        [nan],
#        ['No'],
#        ['Yes'],
#        ['Yes'],
#        ['No'],
#        ['Yes'],
#        ['No'],
#        ['Yes']], dtype=object)

# %%
imputer.fit(df.iloc[:,3:].values)
df.iloc[:,3:] = imputer.transform(df.iloc[:,3:].values)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer.fit(df.iloc[:,:1].values)
df.iloc[:,:1] = imputer.transform(df.iloc[:,:1].values)
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.values
# Out:
# array([['France', 44.0, 72000.0, 'Yes'],
#        ['Spain', 27.0, 48000.0, 'Yes'],
#        ['France', 30.0, 54000.0, 'Yes'],
#        ['Spain', 38.0, 61000.0, 'No'],
#        ['Germany', 40.0, 48000.0, 'Yes'],
#        ['France', 35.0, 58000.0, 'Yes'],
#        ['Spain', 27.0, 52000.0, 'No'],
#        ['France', 48.0, 79000.0, 'Yes'],
#        ['Germany', 50.0, 83000.0, 'No'],
#        ['France', 37.0, 67000.0, 'Yes']], dtype=object)

# %%
imputer= SimpleImputer(missing_values = np.nan,strategy='most_frequent')
imputer.fit(df.iloc[:,:].values)
# imputer.fit(df.iloc[:,3:].values)
df.iloc[:,:] = imputer.transform(df.iloc[:,:].values)
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
