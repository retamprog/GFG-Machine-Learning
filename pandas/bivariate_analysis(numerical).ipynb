# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('Titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# scatterplot helps in establishing the relationship between two numerical data

# %%
sns.scatterplot(x='age',y='fare',hue='sex',size='sex',data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(x='age',y='fare',hue='survived',size='sex',data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df2=sns.load_dataset('tips')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',size='smoker',data=df2)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# joinplot
#gives both the distribution along with the scatterplot

# %%
sns.jointplot(x='total_bill',y='tip',kind='scatter',color='red',data=df2)

# %%
sns.jointplot(x='total_bill',y='tip',kind='scatter',color='red',hue='sex',data=df2)

# %%
sns.jointplot(x='total_bill',y='tip',color='red',data=df2,kind='reg')

# %%
numeric_df = df2.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# %%
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('dowjones')
data.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
# lineplot

# %%
sns.lineplot(x='Date',y='Price',data=data)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    649 non-null    datetime64[ns]
#  1   Price   649 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 10.3 KB

# %%
data['Month']=data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# %%
data
# Out:
#           Date   Price  Month  Year
# 0   1914-12-01   55.00     12  1914
# 1   1915-01-01   56.55      1  1915
# 2   1915-02-01   56.00      2  1915
# 3   1915-03-01   58.30      3  1915
# 4   1915-04-01   66.45      4  1915
# ..         ...     ...    ...   ...
# 644 1968-08-01  883.72      8  1968
# 645 1968-09-01  922.80      9  1968
# 646 1968-10-01  955.47     10  1968
# 647 1968-11-01  964.12     11  1968
# 648 1968-12-01  965.39     12  1968
#
# [649 rows x 4 columns]

# %%
sns.lineplot(x='Date',y='Price',data=data[data['Year']==1925])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>
